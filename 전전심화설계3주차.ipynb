# %% [markdown]
# <a href="https://colab.research.google.com/github/seungsdew/-/blob/main/%EC%A0%84%EC%A0%84%EC%8B%AC%ED%99%94%EC%84%A4%EA%B3%843%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python

# %%
import cv2
from google.colab.patches import cv2_imshow
image = cv2.imread('example.jpg') #이미지 읽기

#이미지 표시
cv2_imshow(image)
cv2.waitKey(0) #사용자 입력 대기
cv2.destroyAllWindows() # 이미지 창이 열리고 사용자가 아무 키나 누를 때까지 대기한 후 모든 창이 닫힘, cv2.destroyAllWindows() 함수는 열린 모든 창을 일괄적으로 닫는 데 사용됨

#이미지 저장
cv2.imwrite('example_copy.png',image)
# Out:
# <PIL.Image.Image image mode=RGB size=206x206>
# True

# %%
# !pip install pillow

# %%
from PIL import Image

#이미지 읽기
image = Image.open('example.jpg')

#이미지 표시
image.show()

#이미지 저장
image.save('example_copy_pillow.png')

# %%
# 이미지 크롭
cropped = image.crop((50,50,200,200))
cropped.show()

# 이미지 회전
rotated = image.rotate(90)
rotated.show()

# %%
# !pip install torch torchvision
import torch
# MLP 신경망 클래스 정의
class MLP(nn.Module) :
  def __init__(self) :
    super().__init__()

    # 첫 번째 레이어
    self.layor0 = nn.Sequential(
        nn.Linear(784, 256), # 입력 크기: 784, 출력 크기: 256
        nn.ReLU() # ReLU Activation Function 적용
    )

    # 두 번째 레이어
    self.layor1 = nn.Sequential(
        nn.Linear(256, 64), # 입력 크기: 256, 출력 크기: 64
        nn.ReLU() # ReLU Activation Function 적용
    )

    # 세 번째 레이어
    self.head = nn.Sequential(
        nn.Linear(64, 10), # 입력 크기: 64, 출력 크기: 10
        nn.ReLU() # ReLU Activation Function 적용
    )

  def forward(self, x: torch.Tensor) :
    x = x.flaten(start_dim=1) # 2D 이미지를 1D 벡터로 펼치기
    x = self.layor0(x) # 첫 번째 레이어 적용
    x = self.layor1(x) # 두 번째 레이어 적용
    x = self.head(x) # 마지막 레이어 적용
    return x
# Out:
#   File "<ipython-input-19-ac22fd85ff5c>", line 4
#     class MLP(nn.Module) :
#                           ^
# SyntaxError: incomplete input
